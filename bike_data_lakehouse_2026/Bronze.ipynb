-- %% [markdown]
-- # Bronze ingestion
-- Load CRM and ERP CSV files from the Unity Catalog volume into managed Delta tables.

-- %% [markdown]
-- ## Load `cust_info.csv`

-- %%
CREATE OR REPLACE TEMPORARY VIEW cust_info_csv
USING CSV
OPTIONS (
  path '/Volumes/workspace/bronze/source_systems/source_crm/cust_info.csv',
  header 'true',
  inferSchema 'true'
);

CREATE OR REPLACE TABLE workspace.bronze.crm_cust_info
USING DELTA
AS SELECT * FROM cust_info_csv;

-- %% [markdown]
-- ## Load `prd_info.csv`

-- %%
CREATE OR REPLACE TEMPORARY VIEW prd_info_csv
USING CSV
OPTIONS (
  path '/Volumes/workspace/bronze/source_systems/source_crm/prd_info.csv',
  header 'true',
  inferSchema 'true'
);

CREATE OR REPLACE TABLE workspace.bronze.crm_prd_info
USING DELTA
AS SELECT * FROM prd_info_csv;

-- %% [markdown]
-- ## Load `sales_details.csv`

-- %%
CREATE OR REPLACE TEMPORARY VIEW sales_details_csv
USING CSV
OPTIONS (
  path '/Volumes/workspace/bronze/source_systems/source_crm/sales_details.csv',
  header 'true',
  inferSchema 'true'
);

CREATE OR REPLACE TABLE workspace.bronze.crm_sales_details
USING DELTA
AS SELECT * FROM sales_details_csv;

-- %% [markdown]
-- ## Load `CUST_AZ12.csv`

-- %%
CREATE OR REPLACE TEMPORARY VIEW cust_az12_csv
USING CSV
OPTIONS (
  path '/Volumes/workspace/bronze/source_systems/source_erp/CUST_AZ12.csv',
  header 'true',
  inferSchema 'true'
);

CREATE OR REPLACE TABLE workspace.bronze.erp_cust_az12
USING DELTA
AS SELECT * FROM cust_az12_csv;

-- %% [markdown]
-- ## Load `LOC_A101.csv`

-- %%
CREATE OR REPLACE TEMPORARY VIEW loc_a101_csv
USING CSV
OPTIONS (
  path '/Volumes/workspace/bronze/source_systems/source_erp/LOC_A101.csv',
  header 'true',
  inferSchema 'true'
);

CREATE OR REPLACE TABLE workspace.bronze.erp_loc_a101
USING DELTA
AS SELECT * FROM loc_a101_csv;

-- %% [markdown]
-- ## Load `PX_CAT_G1V2.csv`

-- %%
CREATE OR REPLACE TEMPORARY VIEW px_cat_g1v2_csv
USING CSV
OPTIONS (
  path '/Volumes/workspace/bronze/source_systems/source_erp/PX_CAT_G1V2.csv',
  header 'true',
  inferSchema 'true'
);

CREATE OR REPLACE TABLE workspace.bronze.erp_px_cat_g1v2
USING DELTA
AS SELECT * FROM px_cat_g1v2_csv;
